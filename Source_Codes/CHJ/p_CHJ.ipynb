# %%
# 1 chj

import pandas as pd
import numpy as np
import pandas as pd

DATA_PATH = 'C:/Users/campus3S025/Desktop/imbank_streamlit_demo/dataset/'
csv_names = [
    'iMBANK_CARD_DATA_2021.csv', 
    'iMBANK_CARD_DATA_2022.csv', 
    'iMBANK_CARD_DATA_2023.csv', 
    'iMBANK_CUSTOMER_DATA_2021.csv', 
    'iMBANK_CUSTOMER_DATA_2022.csv', 
    'iMBANK_CUSTOMER_DATA_2023.csv'
    ]
datasets = {}
def read_data(csv_names):
    for i in range(len(csv_names)):
        datasets[f"data_{i+1}"] = pd.read_csv(f"{DATA_PATH}{csv_names[i]}", encoding='cp949')

        print(f'data input complete! : {csv_names[i]} as data_{i+1}')
    print('All data read complete!')

read_data(csv_names)
# DATA_PATH = ('C:/Users/campus3S025/Desktop/imbank_streamlit_demo/dataset/')

# df1 = f'{DATA_PATH}iMBANK_CARD_DATA_2023.csv'
datasets['data_2']

# %%
# 2 chj

import pandas as pd
import numpy as np
import pandas as pd

DATA_PATH = 'C:/Users/campus3S025/Desktop/imbank_streamlit_demo/dataset/'
csv_names = [
    'iMBANK_CARD_DATA_2021.csv', 
    'iMBANK_CARD_DATA_2022.csv', 
    'iMBANK_CARD_DATA_2023.csv', 
    'iMBANK_CUSTOMER_DATA_2021.csv', 
    'iMBANK_CUSTOMER_DATA_2022.csv', 
    'iMBANK_CUSTOMER_DATA_2023.csv'
    ]
datasets = {}
def read_data(csv_names):
    for i in range(len(csv_names)):
        datasets[f"data_{i+1}"] = pd.read_csv(f"{DATA_PATH}{csv_names[i]}", encoding='cp949')

        print(f'data input complete! : {csv_names[i]} as data_{i+1}')
    print('All data read complete!')

read_data(csv_names)
# DATA_PATH = ('C:/Users/campus3S025/Desktop/imbank_streamlit_demo/dataset/')

# df1 = f'{DATA_PATH}iMBANK_CARD_DATA_2023.csv'
datasets['data_2']

# %%
# 3 chj

import pandas as pd
import numpy as np
DATA_PATH = 'C:/Users/campus3S025/Desktop/imbank_streamlit_demo/dataset'
data_21 = pd.read_csv(f'{DATA_PATH}/card_base_2021.csv')
data_22 = pd.read_csv(f'{DATA_PATH}/card_base_2022.csv')
data_23 = pd.read_csv(f'{DATA_PATH}/card_base_2023.csv')
print(data_21.shape, data_22.shape, data_23.shape)
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
data_23.info()
data_23.tail()
"""import numpy as np
import pandas as pd
from sklearn.utils import resample

# 예시 데이터 생성
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)  # 모집단에서 얻은 표본 데이터

# 부트스트랩 샘플링 함수
def bootstrap_sample(data, n_iterations):
    bootstrap_samples = []
    for i in range(n_iterations):
        sample = resample(data, replace=True, n_samples=len(data))
        bootstrap_samples.append(sample)
    return bootstrap_samples

# 부트스트랩 통계량 계산 함수
def bootstrap_statistics(samples, statistic_func):
    statistics = [statistic_func(sample) for sample in samples]
    return statistics

# 부트스트랩 샘플 생성
n_iterations = 1000
bootstrap_samples = bootstrap_sample(data, n_iterations)

# 부트스트랩 평균 계산
bootstrap_means = bootstrap_statistics(bootstrap_samples, np.mean)

# 부트스트랩 분산 계산 (예시로 추가)
bootstrap_variances = bootstrap_statistics(bootstrap_samples, np.var)

# 신뢰 구간 계산
confidence_level = 95
lower_percentile = (100 - confidence_level) / 2
upper_percentile = 100 - lower_percentile
mean_confidence_interval = np.percentile(bootstrap_means, [lower_percentile, upper_percentile])
variance_confidence_interval = np.percentile(bootstrap_variances, [lower_percentile, upper_percentile])

# 결과 출력
print(f'부트스트랩 평균 신뢰 구간: {mean_confidence_interval}')
print(f'부트스트랩 분산 신뢰 구간: {variance_confidence_interval}')
"""
"""
import numpy as np
import pandas as pd

# 예시 데이터 생성 (표본집단)
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=100)  # 평균 50, 표준편차 10인 정규분포

# pandas 데이터프레임으로 변환
df = pd.DataFrame(sample_data, columns=['values'])

# 주요 통계량 계산
mean = df['values'].mean()                # 평균
variance = df['values'].var()             # 분산
std_dev = df['values'].std()              # 표준편차
median = df['values'].median()            # 중앙값
quantiles = df['values'].quantile([0.25, 0.5, 0.75])  # 사분위수
min_value = df['values'].min()            # 최소값
max_value = df['values'].max()            # 최대값

# 결과 출력
print(f'평균: {mean}')
print(f'분산: {variance}')
print(f'표준편차: {std_dev}')
print(f'중앙값: {median}')
print(f'사분위수 (25%, 50%, 75%):\n{quantiles}')
print(f'최소값: {min_value}')
print(f'최대값: {max_value}')
"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 예시 데이터 생성
np.random.seed(42)
data1 = pd.DataFrame({
    'value': np.random.normal(loc=50, scale=10, size=100),
    'category': 'A'
})

data2 = pd.DataFrame({
    'value': np.random.normal(loc=60, scale=15, size=100),
    'category': 'B'
})

data3 = pd.DataFrame({
    'value': np.random.normal(loc=70, scale=20, size=100),
    'category': 'C'
})

# 데이터 합치기
combined_data = pd.concat([data1, data2, data3])

# 시각화
plt.figure(figsize=(12, 6))

# 히스토그램
plt.subplot(1, 2, 1)
sns.histplot(data=combined_data, x='value', hue='category', element='step', stat='density', common_norm=False)
plt.title('Histogram')

# 박스플롯
plt.subplot(1, 2, 2)
sns.boxplot(data=combined_data, x='category', y='value')
plt.title('Boxplot')

plt.tight_layout()
plt.show()
# concat

DATA_PATH = 'C:/Users/campus3S025/Desktop/imbank_streamlit_demo/dataset'

data_21 = pd.read_csv(f'{DATA_PATH}/card_base_2021.csv')
data_22 = pd.read_csv(f'{DATA_PATH}/card_base_2022.csv')
data_23 = pd.read_csv(f'{DATA_PATH}/card_base_2023.csv')

combined_data = pd.concat([data_21, data_22, data_23], ignore_index=True)

print(combined_data.head())
print(combined_data.tail())
print(combined_data.info())
import matplotlib.pyplot as plt
import squarify

plt.figure(figsize=(12, 8))
squarify.plot(sizes=grade_ratios, label=grade_ratios.index, alpha=.8)
plt.title('Customer Grade Ratios Treemap')
plt.axis('off')  # 축 제거
plt.show()

# %%
# 4 chj

import pandas as pd
import numpy as np
DATA_PATH = 'C:/Users/campus3S025/Desktop/imbank_streamlit_demo/dataset'
data_capital = pd.read_csv(f'{DATA_PATH}/capital_data.csv')
print(data_capital.shape)
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
data_capital.info()
# 식생활, 소매 및 생활용품, 서비스 및 여가, 교통 및 물류, 기타
data_capital.tail()
is_present = '중구' in data_capital['가맹점_시군구'].values
print(is_present)
data_capital = pd.DataFrame(data_capital)

count = data_capital['가맹점_시군구'].value_counts().get('중구', 0)
matching_rows = data_capital[data_capital['가맹점_시군구'] == '중구']

print(f"중구 항목의 개수: {count}")
print("중구 항목의 데이터:")
print(matching_rows)
value_counts = data_capital['가맹점_시군구'].value_counts()

print("각 항목의 개수:")
print(value_counts)
print()

# 각 항목에 해당하는 데이터를 나열
for item in value_counts.index:
    matching_rows = data_capital[data_capital['가맹점_시군구'] == item]
    print(f"{item} 항목의 데이터 ({value_counts[item]}개):")
    print(matching_rows)
    print()

# %%
# 5 chj

import pandas as pd
import numpy as np
DATA_PATH = 'C:/Users/campus3S025/Desktop/imbank_streamlit_demo/dataset'
capital_data = pd.read_csv(f'{DATA_PATH}/capital_data_1.csv')
print(capital_data.shape)
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
capital_data.info()
# 식생활, 소매 및 생활용품, 서비스 및 여가, 교통 및 물류, 기타
capital_data.tail()
is_present = '기타' in capital_data['가맹점업종명_범주화'].values
print(is_present)
capital_data = pd.DataFrame(capital_data)

count = capital_data['가맹점업종명_범주화'].value_counts().get('기타', 0)
matching_rows = capital_data[capital_data['가맹점업종명_범주화'] == '기타']

print(f"기타 항목의 개수: {count}")
print("기타 항목의 데이터:")
print(matching_rows)
capital_data[['가맹점업종명','가맹점업종명_범주화']][capital_data['가맹점업종명_범주화'] == '인터넷P/G']
capital_data[['가맹점업종명']][capital_data['가맹점업종명_범주화'] == '기타'].value_counts().reset_index()
capital_data[['가맹점업종명_범주화', '가맹점업종명']][capital_data['가맹점업종명_범주화'] == '인터넷P/G'].value_counts().reset_index()
result = capital_data[['가맹점업종명_범주화', '가맹점업종명']][capital_data['가맹점업종명_범주화'] == '인터넷P/G'].value_counts().reset_index(name='count')
print(result)

# '가맹점업종명_범주화'가 '인터넷P/G'인 행 필터링
filtered_data = capital_data[capital_data['가맹점업종명_범주화'] == '인터넷P/G']

# '가맹점업종명' 열의 값만 출력
print(filtered_data[['가맹점업종명']])
# '가맹점업종명_범주화'가 '인터넷P/G'인 행 필터링
filtered_data = capital_data[capital_data['가맹점업종명_범주화'] == '인터넷P/G']

# '가맹점업종명_범주화'와 '가맹점업종명' 두 열을 같이 출력
print(filtered_data[['가맹점업종명_범주화', '가맹점업종명']])
